# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('.'))))

from backend.services.halilit_brand_registry import HalilitBrandRegistry

registry = HalilitBrandRegistry()
roster = registry.fetch_official_roster()
roland_entry = next((b for b in roster if b['slug'] == 'roland'), None)

if roland_entry:
    print(f"Found Roland: {roland_entry}")
else:
    print("Roland not found in registry")
